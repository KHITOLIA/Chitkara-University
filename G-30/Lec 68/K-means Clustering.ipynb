# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples=1000, n_features=2, centers=5, random_state=100)

# %%
# points.shape

# %%
plt.scatter(X[:, 0], X[:, 1], c = _)

# %% [markdown]
# # Initialize the center points (clusters)

# %%
k = 5
color = ['green','red','blue', 'cyan', 'yellow']

clusters = {}

for i in range(k):
    
    center = np.random.randint(-12, 10, size = (2))
    point = []
    
    cluster = {
        'center':center,
        'point':point,
        'color':color[i]
    }
    clusters[i] = cluster

# %%
clusters
# Out:
# {0: {'center': array([-8,  2]), 'point': [], 'color': 'green'},
#  1: {'center': array([-1,  2]), 'point': [], 'color': 'red'},
#  2: {'center': array([ 2, -4]), 'point': [], 'color': 'blue'},
#  3: {'center': array([-7,  7]), 'point': [], 'color': 'cyan'},
#  4: {'center': array([6, 8]), 'point': [], 'color': 'yellow'}}

# %%
def distance_formula(p1, p2):
    dist = ((p1[0]-p2[0])**2 + (p1[1] - p2[1])**2)**0.5
    return dist

# %%
print(distance_formula(clusters[0]['center'], X[0]))
# Out:
# 7.394407131658412

# %%
# E - Step

def point_to_cluster(clusters):
    
    for i in range(X.shape[0]):
        
        distance = []
        
        for j in range(k):
            
            dist = distance_formula(clusters[j]['center'], X[i])
            
            distance.append(dist)
        
        belong_cluster = np.argmin(distance)
        
        clusters[belong_cluster]['point'].append(X[i])

# %%
# M - Step
def update_cluster(clusters):
    
    for i in range(k):
        
        p = np.array(clusters[i]['point'])
        
        if p.shape[0]>0:
            
            u = p.mean(axis = 0)
            
            clusters[i]['center'] = u
            clusters[i]['point'] = []

# %%
def plot_cluster(clusters):
    
    for i in range(k):
        
        p = np.array(clusters[i]['point'])
        
        if p.shape[0]>0:
            
            plt.scatter(p[:, 0], p[:, 1], c = clusters[i]['color'])
            
        else:
            pass
        
        cluster_center = clusters[i]['center']
        plt.scatter(cluster_center[0], cluster_center[1], c = 'black')

# %%
point_to_cluster(clusters)
plot_cluster(clusters)

# %%
update_cluster(clusters)

# %%
point_to_cluster(clusters)
plot_cluster(clusters)

# %%
point_to_cluster(clusters)
plot_cluster(clusters)
update_cluster(clusters)

# %%
clusters
# Out:
# {0: {'center': array([-8.6797183 , -3.26339768]),
#   'point': [],
#   'color': 'green'},
#  1: {'center': array([-1.04939013,  6.20037078]), 'point': [], 'color': 'red'},
#  2: {'center': array([ 0.88140395, -4.44945081]),
#   'point': [],
#   'color': 'blue'},
#  3: {'center': array([-2.59426611,  7.17078662]),
#   'point': [],
#   'color': 'cyan'},
#  4: {'center': array([3.64321449, 6.56923206]),
#   'point': [],
#   'color': 'yellow'}}
